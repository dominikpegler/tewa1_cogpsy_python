# %% [markdown]
# tewa 1: final project
# ---

# %% [markdown]
# https://spotipy.readthedocs.io/en/2.19.0/

# %% [raw]
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import json

with open("credentials.json") as fo:
    credentials = json.load(fo)

CLIENT_ID = credentials["CLIENT_ID"]
CLIENT_SECRET = credentials["CLIENT_SECRET"]
TOKEN = credentials["TOKEN"]

# %%
CLIENT_ID
# Out:
# 'ef5b76301d4f4c4ea0843e0083feec29'

# %%
CLIENT_SECRET
# Out:
# 'fd94c715570a4a869281ebec48ae076a'

# %%
TOKEN
# Out:
# 'BQCwUrBqucCX39etXi7hg-y_vd85ZraNm66z22fwQcbJZFGUSHe9eU50Wdb83_HXN9_G4DX_DrklnyuBbOIBfqS0W5ljIp9EAizHChmu0BYIRBuPLVfVnRZM3MS6tuB6cXalsC5aPBBygBMd71UyAmNr9z05pnPiEtYpJrinuL0tXQwS'

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)

#sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
scope = "user-library-read"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID, client_secret=CLIENT_SECRET,scope=scope))
# Out:
# ---------------------------------------------------------------------------
# SpotifyOauthError                         Traceback (most recent call last)
# /tmp/ipykernel_8818/2093851246.py in <module>
#       3 #sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
#       4 scope = "user-library-read"
# ----> 5 sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID, client_secret=CLIENT_SECRET,scope=scope))
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/spotipy/oauth2.py in __init__(self, client_id, client_secret, redirect_uri, state, scope, cache_path, username, proxies, show_dialog, requests_session, requests_timeout, open_browser, cache_handler)
#     332         self.client_id = client_id
#     333         self.client_secret = client_secret
# --> 334         self.redirect_uri = redirect_uri
#     335         self.state = state
#     336         self.scope = self._normalize_scope(scope)
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/spotipy/oauth2.py in redirect_uri(self, val)
#     108     @redirect_uri.setter
#     109     def redirect_uri(self, val):
# --> 110         self._redirect_uri = _ensure_value(val, "redirect_uri")
#     111
#     112     @staticmethod
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/spotipy/oauth2.py in _ensure_value(value, env_key)
#      68             env_val,
#      69         )
# ---> 70         raise SpotifyOauthError(msg)
#      71     return _val
#      72
#
# SpotifyOauthError: No redirect_uri. Pass it or set a SPOTIPY_REDIRECT_URI environment variable.

# %%
results = sp.current_user_saved_tracks()
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/me/tracks with Params: {'limit': 20, 'offset': 0, 'market': None} returned 401 due to Missing token
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     244
# --> 245             response.raise_for_status()
#     246             results = response.json()
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/requests/models.py in raise_for_status(self)
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/me/tracks?limit=20&offset=0
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# /tmp/ipykernel_8818/737512484.py in <module>
# ----> 1 results = sp.current_user_saved_tracks()
#       2 for idx, item in enumerate(results['items']):
#       3     track = item['track']
#       4     print(idx, track['artists'][0]['name'], " – ", track['name'])
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/spotipy/client.py in current_user_saved_tracks(self, limit, offset, market)
#    1230
#    1231         """
# -> 1232         return self._get("me/tracks", limit=limit, offset=offset, market=market)
#    1233
#    1234     def current_user_saved_tracks_add(self, tracks=None):
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~/miniconda3/envs/py39/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     265             )
#     266
# --> 267             raise SpotifyException(
#     268                 response.status_code,
#     269                 -1,
#
# SpotifyException: http status: 401, code:-1 - https://api.spotify.com/v1/me/tracks?limit=20&offset=0:
#  Missing token, reason: None

# %% [raw]
# results = sp.current_user_saved_tracks()
# for idx, item in enumerate(results['items']):
#     track = item['track']
#     print(idx, track['artists'][0]['name'], " – ", track['name'])

# %%
artist_name = []
track_name = []
track_popularity = []
artist_id = []
track_id = []
for i in range(0,100,50):
    track_results = sp.search(q='year:2021', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_id.append(t['artists'][0]['id'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])

# %%
import pandas as pd
track_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'track_popularity' : track_popularity, 'artist_id' : artist_id})
print(track_df.shape)
track_df
# Out:
# (100, 5)
#                          artist_name  \
# 0         Carolina Gaitán - La Gaita
# 1                          Dj Biffen
# 2                           Coldplay
# 3   Elvis Costello & The Attractions
# 4                     Olivia Rodrigo
# ..                               ...
# 95                  Armin van Buuren
# 96                              JVKE
# 97                             AVIRA
# 98                      Taylor Swift
# 99                         Tinlicker
#
#                                            track_name                track_id  \
# 0                           We Don't Talk About Bruno  52xJxFP6TqMuO4Yt0eOkMz
# 1   Merry Christmas and Happy New Year 2021 - Radi...  7h7yPyss4MIBVPXVeF83vg
# 2                                         My Universe  3FeVmId7tL5YN8B7R3imoM
# 3                          Pump It Up - 2021 Remaster  3oyc1mIdCBGaU55wX7otqM
# 4                                            good 4 u  4ZtFanR9U6ndgddUvNcjcG
# ..                                                ...                     ...
# 95                         Hold On (Mixed) - Club Mix  49bB6BilfuQycwRTt8faR3
# 96            this is what falling in love feels like  4UG2Fm0E98LhE2dlNxiAXx
# 97                                      Ocean (Mixed)  5LR1lsoTR1rKX1C1mvYlPL
# 98  All Too Well (10 Minute Version) (Taylor's Ver...  5enxwA8aAbwZbf5qCHORXi
# 99                                   Children (Mixed)  2jIyY91zgWZGu0Fqhp0PSr
#
#     track_popularity               artist_id
# 0                 87  29PgYEggDV3cDP9QYTogwv
# 1                 27  7K54lZmkO9dwqe22N27ftb
# 2                 86  4gzpq5DPGxSnKTe4SA8HAU
# 3                 61  4qmHkMxr6pTWh5Zo74odpH
# 4                 90  1McMsnEElThX1knmY4oliG
# ..               ...                     ...
# 95                36  0SfsnGyD8FpIN4U4WCkBZ5
# 96                83  164Uj4eKjl6zTBKfJLFKKK
# 97                36  7rznn3BVOuA5jyPB275jmS
# 98                83  06HL4z0CvFAxyc27GXpf02
# 99                37  5EmEZjq8eHEC6qFnT63Lza
#
# [100 rows x 5 columns]

# %%
artist_popularity = []
artist_genres = []
artist_followers = []
for a_id in track_df.artist_id:
    artist = sp.artist(a_id)
    artist_popularity.append(artist['popularity'])
    artist_genres.append(artist['genres'])
    artist_followers.append(artist['followers']['total'])

# %%
track_df = track_df.assign(artist_popularity=artist_popularity, artist_genres=artist_genres, artist_followers=artist_followers)
track_df.head()
# Out:
#                         artist_name  \
# 0        Carolina Gaitán - La Gaita
# 1                         Dj Biffen
# 2                          Coldplay
# 3  Elvis Costello & The Attractions
# 4                    Olivia Rodrigo
#
#                                           track_name                track_id  \
# 0                          We Don't Talk About Bruno  52xJxFP6TqMuO4Yt0eOkMz
# 1  Merry Christmas and Happy New Year 2021 - Radi...  7h7yPyss4MIBVPXVeF83vg
# 2                                        My Universe  3FeVmId7tL5YN8B7R3imoM
# 3                         Pump It Up - 2021 Remaster  3oyc1mIdCBGaU55wX7otqM
# 4                                           good 4 u  4ZtFanR9U6ndgddUvNcjcG
#
#    track_popularity               artist_id  artist_popularity  \
# 0                87  29PgYEggDV3cDP9QYTogwv                 76
# 1                27  7K54lZmkO9dwqe22N27ftb                 24
# 2                86  4gzpq5DPGxSnKTe4SA8HAU                 92
# 3                61  4qmHkMxr6pTWh5Zo74odpH                 59
# 4                90  1McMsnEElThX1knmY4oliG                 91
#
#                                        artist_genres  artist_followers
# 0                                                 []             27536
# 1                                                 []                27
# 2                              [permanent wave, pop]          35437564
# 3  [art rock, folk rock, mellow gold, new wave po...            227249
# 4                                              [pop]          16179831

# %%
track_features = []
for t_id in track_df['track_id']:
    af = sp.audio_features(t_id)
    track_features.append(af)
tf_df = pd.DataFrame(columns = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])
for item in track_features:
    for feat in item:
        tf_df = tf_df.append(feat, ignore_index=True)
tf_df.head()
# Out:
#    danceability  energy key  loudness mode  speechiness  acousticness  \
# 0         0.577   0.450   0    -8.516    0       0.0834       0.35700
# 1         0.887   0.633   8   -10.453    1       0.0660       0.06290
# 2         0.588   0.701   9    -6.390    1       0.0402       0.00813
# 3         0.645   0.809  11    -6.120    1       0.0385       0.00921
# 4         0.563   0.664   9    -5.044    1       0.1540       0.33500
#
#   instrumentalness  liveness  valence    tempo            type  \
# 0                0    0.1110    0.830  205.863  audio_features
# 1            0.922    0.0637    0.849  130.023  audio_features
# 2                0    0.2000    0.443  104.988  audio_features
# 3          0.00108    0.1060    0.966  138.978  audio_features
# 4                0    0.0849    0.688  166.928  audio_features
#
#                        id                                   uri  \
# 0  52xJxFP6TqMuO4Yt0eOkMz  spotify:track:52xJxFP6TqMuO4Yt0eOkMz
# 1  7h7yPyss4MIBVPXVeF83vg  spotify:track:7h7yPyss4MIBVPXVeF83vg
# 2  3FeVmId7tL5YN8B7R3imoM  spotify:track:3FeVmId7tL5YN8B7R3imoM
# 3  3oyc1mIdCBGaU55wX7otqM  spotify:track:3oyc1mIdCBGaU55wX7otqM
# 4  4ZtFanR9U6ndgddUvNcjcG  spotify:track:4ZtFanR9U6ndgddUvNcjcG
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/52xJxFP6TqMu...
# 1  https://api.spotify.com/v1/tracks/7h7yPyss4MIB...
# 2  https://api.spotify.com/v1/tracks/3FeVmId7tL5Y...
# 3  https://api.spotify.com/v1/tracks/3oyc1mIdCBGa...
# 4  https://api.spotify.com/v1/tracks/4ZtFanR9U6nd...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/52xJ...      216120
# 1  https://api.spotify.com/v1/audio-analysis/7h7y...      176363
# 2  https://api.spotify.com/v1/audio-analysis/3FeV...      228000
# 3  https://api.spotify.com/v1/audio-analysis/3oyc...      196680
# 4  https://api.spotify.com/v1/audio-analysis/4ZtF...      178147
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4

# %%
cols_to_drop2 = ['key','mode','type', 'uri','track_href','analysis_url']
tf_df = tf_df.drop(columns=cols_to_drop2)
print(track_df.info())
print(tf_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist_name        100 non-null    object
#  1   track_name         100 non-null    object
#  2   track_id           100 non-null    object
#  3   track_popularity   100 non-null    int64
#  4   artist_id          100 non-null    object
#  5   artist_popularity  100 non-null    int64
#  6   artist_genres      100 non-null    object
#  7   artist_followers   100 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 6.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      100 non-null    float64
#  1   energy            100 non-null    float64
#  2   loudness          100 non-null    float64
#  3   speechiness       100 non-null    float64
#  4   acousticness      100 non-null    float64
#  5   instrumentalness  100 non-null    object
#  6   liveness          100 non-null    float64
#  7   valence           100 non-null    float64
#  8   tempo             100 non-null    float64
#  9   id                100 non-null    object
#  10  duration_ms       100 non-null    object
#  11  time_signature    100 non-null    object
# dtypes: float64(8), object(4)
# memory usage: 9.5+ KB
# None

# %%
track_df['artist_name'] = track_df['artist_name'].astype("string")
track_df['track_name'] = track_df['track_name'].astype("string")
track_df['track_id'] = track_df['track_id'].astype("string")
track_df['artist_id'] = track_df['artist_id'].astype("string")
tf_df['duration_ms'] = pd.to_numeric(tf_df['duration_ms'])
tf_df['instrumentalness'] = pd.to_numeric(tf_df['instrumentalness'])
tf_df['time_signature'] = tf_df['time_signature'].astype("category")
print(track_df.info())
print(tf_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist_name        100 non-null    string
#  1   track_name         100 non-null    string
#  2   track_id           100 non-null    string
#  3   track_popularity   100 non-null    int64
#  4   artist_id          100 non-null    string
#  5   artist_popularity  100 non-null    int64
#  6   artist_genres      100 non-null    object
#  7   artist_followers   100 non-null    int64
# dtypes: int64(3), object(1), string(4)
# memory usage: 6.4+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      100 non-null    float64
#  1   energy            100 non-null    float64
#  2   loudness          100 non-null    float64
#  3   speechiness       100 non-null    float64
#  4   acousticness      100 non-null    float64
#  5   instrumentalness  100 non-null    float64
#  6   liveness          100 non-null    float64
#  7   valence           100 non-null    float64
#  8   tempo             100 non-null    float64
#  9   id                100 non-null    object
#  10  duration_ms       100 non-null    int64
#  11  time_signature    100 non-null    category
# dtypes: category(1), float64(9), int64(1), object(1)
# memory usage: 8.9+ KB
# None

# %%
track_df.sort_values(by=['track_popularity'], ascending=False)[['track_name', 'artist_name']].head(20)
# Out:
#                                            track_name      artist_name
# 24                                            abcdefu            GAYLE
# 8                                               Woman         Doja Cat
# 16  Enemy (with JID) - from the series Arcane Leag...  Imagine Dragons
# 12                                  THATS WHAT I WANT        Lil Nas X
# 60                                          The Motto           Tiësto
# 54                                         Bad Habits       Ed Sheeran
# 20                          STAY (with Justin Bieber)    The Kid LAROI
# 48                            Cold Heart - PNAU Remix       Elton John
# 4                                            good 4 u   Olivia Rodrigo
# 38                                            Shivers       Ed Sheeran
# 68                                           Yonaguni        Bad Bunny
# 78  Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)            Tainy
# 28                  INDUSTRY BABY (feat. Jack Harlow)        Lil Nas X
# 44                                              Ghost    Justin Bieber
# 26                                            traitor   Olivia Rodrigo
# 90                                              Pepas          Farruko
# 52                                    drivers license   Olivia Rodrigo
# 76                                         Easy On Me            Adele
# 18                                       Need to Know         Doja Cat
# 32                                  Happier Than Ever    Billie Eilish

# %%
by_art_fol = pd.DataFrame(track_df.sort_values(by=['artist_followers'], ascending=False)[['artist_followers','artist_popularity', 'artist_name','artist_genres']])
by_art_fol.astype(str).drop_duplicates().head(20)
# Out:
#    artist_followers artist_popularity       artist_name  \
# 54         96173363                96        Ed Sheeran
# 50         62907605                98             Drake
# 32         61062299                93     Billie Eilish
# 44         59848830                96     Justin Bieber
# 98         52325184                98      Taylor Swift
# 68         47298998               100         Bad Bunny
# 16         39679227                93   Imagine Dragons
# 76         37157408                90             Adele
# 34         36681503                91       Post Malone
# 2          35437564                92          Coldplay
# 8          18112381                94          Doja Cat
# 26         16179831                91    Olivia Rodrigo
# 90         12818374                90           Farruko
# 28         10598206                89         Lil Nas X
# 48          9171154                88        Elton John
# 14          8047222                86       Kodak Black
# 56          7645091                87               SZA
# 60          6324141                87            Tiësto
# 51          4106864                78  Armin van Buuren
# 94          3952720                90          Lil Durk
#
#                                         artist_genres
# 54                                  ['pop', 'uk pop']
# 50  ['canadian hip hop', 'canadian pop', 'hip hop'...
# 32                   ['art pop', 'electropop', 'pop']
# 44                            ['canadian pop', 'pop']
# 98                                            ['pop']
# 68              ['latin', 'reggaeton', 'trap latino']
# 16                            ['modern rock', 'rock']
# 76      ['british soul', 'pop', 'pop soul', 'uk pop']
# 34                  ['dfw rap', 'melodic rap', 'rap']
# 2                           ['permanent wave', 'pop']
# 8                                ['dance pop', 'pop']
# 26                                            ['pop']
# 90  ['latin', 'latin hip hop', 'reggaeton', 'trap ...
# 28                          ['lgbtq+ hip hop', 'pop']
# 48         ['glam rock', 'mellow gold', 'piano rock']
# 14  ['florida rap', 'hip hop', 'melodic rap', 'mia...
# 56                                     ['pop', 'r&b']
# 60  ['big room', 'brostep', 'dance pop', 'dutch ed...
# 51  ['dutch trance', 'edm', 'pop dance', 'progress...
# 94  ['chicago drill', 'chicago rap', 'drill', 'hip...

# %%
def to_1D(series):
    return pd.Series([x for _list in series for x in _list])
to_1D(track_df['artist_genres']).value_counts().head(20)
# Out:
# pop                   24
# trance                16
# edm                   15
# progressive house     15
# pop dance             14
# mellow gold           13
# folk rock             13
# rock                  13
# new wave pop          12
# power pop             12
# pub rock              12
# roots rock            12
# art rock              12
# uplifting trance       9
# rap                    8
# progressive trance     7
# dance pop              7
# hip hop                7
# canadian pop           5
# dutch trance           5
# dtype: int64

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (14,4))
ax.bar(to_1D(track_df['artist_genres']).value_counts().index[:10],
        to_1D(track_df['artist_genres']).value_counts().values[:10])
ax.set_ylabel("Frequency", size = 12)
ax.set_title("Top genres", size = 14)
# Out:
# Text(0.5, 1.0, 'Top genres')

# %%
top_10_genres = list(to_1D(track_df['artist_genres']).value_counts().index[:20])
top_artists_by_genre = []
for genre in top_10_genres:
    for index, row in by_art_fol.iterrows():
        if genre in row['artist_genres']:
            top_artists_by_genre.append({'artist_name':row['artist_name'], 'artist_genre':genre})
            break
pd.json_normalize(top_artists_by_genre)
# Out:
#                          artist_name        artist_genre
# 0                         Ed Sheeran                 pop
# 1                             Tiësto              trance
# 2                             Tiësto                 edm
# 3                   Armin van Buuren   progressive house
# 4                             Tiësto           pop dance
# 5                         Elton John         mellow gold
# 6   Elvis Costello & The Attractions           folk rock
# 7                    Imagine Dragons                rock
# 8   Elvis Costello & The Attractions        new wave pop
# 9   Elvis Costello & The Attractions           power pop
# 10  Elvis Costello & The Attractions            pub rock
# 11  Elvis Costello & The Attractions          roots rock
# 12  Elvis Costello & The Attractions            art rock
# 13                    Above & Beyond    uplifting trance
# 14                             Drake                 rap
# 15                    Above & Beyond  progressive trance
# 16                          Doja Cat           dance pop
# 17                             Drake             hip hop
# 18                             Drake        canadian pop
# 19                  Armin van Buuren        dutch trance

# %%
by_track_pop = pd.DataFrame(track_df.sort_values(by=['track_popularity'], ascending=False)[['track_popularity','track_name', 'artist_name','artist_genres', 'track_id']])
by_track_pop.astype(str).drop_duplicates().head(20)
top_songs_by_genre = []
for genre in top_10_genres:
      for index, row in by_track_pop.iterrows():
        if genre in row['artist_genres']:
            top_songs_by_genre.append({'track_name':row['track_name'], 'track_popularity':row['track_popularity'],'artist_name':row['artist_name'], 'artist_genre':genre})
            break
pd.json_normalize(top_songs_by_genre)
# Out:
#                                            track_name  track_popularity  \
# 0                                               Woman                91
# 1                                           The Motto                90
# 2                                           The Motto                90
# 3                                 Bloodstream (Mixed)                38
# 4                                           The Motto                90
# 5                             Cold Heart - PNAU Remix                90
# 6                          Pump It Up - 2021 Remaster                61
# 7   Enemy (with JID) - from the series Arcane Leag...                91
# 8                          Pump It Up - 2021 Remaster                61
# 9                          Pump It Up - 2021 Remaster                61
# 10                         Pump It Up - 2021 Remaster                61
# 11                         Pump It Up - 2021 Remaster                61
# 12                         Pump It Up - 2021 Remaster                61
# 13                                Bloodstream (Mixed)                38
# 14                    One Right Now (with The Weeknd)                86
# 15                                Bloodstream (Mixed)                38
# 16                                              Woman                91
# 17        Knife Talk (with 21 Savage ft. Project Pat)                84
# 18                                              Ghost                89
# 19                                Bloodstream (Mixed)                38
#
#                          artist_name        artist_genre
# 0                           Doja Cat                 pop
# 1                             Tiësto              trance
# 2                             Tiësto                 edm
# 3                      Ferry Corsten   progressive house
# 4                             Tiësto           pop dance
# 5                         Elton John         mellow gold
# 6   Elvis Costello & The Attractions           folk rock
# 7                    Imagine Dragons                rock
# 8   Elvis Costello & The Attractions        new wave pop
# 9   Elvis Costello & The Attractions           power pop
# 10  Elvis Costello & The Attractions            pub rock
# 11  Elvis Costello & The Attractions          roots rock
# 12  Elvis Costello & The Attractions            art rock
# 13                     Ferry Corsten    uplifting trance
# 14                       Post Malone                 rap
# 15                     Ferry Corsten  progressive trance
# 16                          Doja Cat           dance pop
# 17                             Drake             hip hop
# 18                     Justin Bieber        canadian pop
# 19                     Ferry Corsten        dutch trance

# %%
import seaborn as sn
sn.set(rc = {'figure.figsize':(12,10)})
sn.heatmap(tf_df.corr(), annot=True)
plt.show()

# %%
sn.set(rc = {'figure.figsize':(20,20)})
sn.jointplot(data=tf_df, x="loudness", y="energy", kind="kde")
